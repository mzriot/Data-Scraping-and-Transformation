# %%
import requests
import pandas as pd
import datetime
import time
import pyodbc as odbc

# %%
api_key = "9c31defb68c5ac281ef53ad13569fa29d295e408"

# %%
endpoint = f"https://api.jcdecaux.com/vls/v1/stations?contract=dublin&apiKey={api_key}"

# %%
resp = requests.get(endpoint)
resp
# Out:
# <Response [200]>

# %%
resp.content
# Out:
# b'[{"number":42,"contract_name":"dublin","name":"SMITHFIELD NORTH","address":"Smithfield North","position":{"lat":53.349562,"lng":-6.278198},"banking":false,"bonus":false,"bike_stands":30,"available_bike_stands":26,"available_bikes":4,"status":"OPEN","last_update":1712657065000},{"number":30,"contract_name":"dublin","name":"PARNELL SQUARE NORTH","address":"Parnell Square North","position":{"lat":53.3537415547453,"lng":-6.26530144781526},"banking":false,"bonus":false,"bike_stands":20,"available_bike_stands":13,"available_bikes":6,"status":"OPEN","last_update":1712657057000},{"number":54,"contract_name":"dublin","name":"CLONMEL STREET","address":"Clonmel Street","position":{"lat":53.336021,"lng":-6.26298},"banking":false,"bonus":false,"bike_stands":33,"available_bike_stands":27,"available_bikes":6,"status":"OPEN","last_update":1712657047000},{"number":108,"contract_name":"dublin","name":"AVONDALE ROAD","address":"Avondale Road","position":{"lat":53.359405,"lng":-6.276142},"banking":fal
# ...

# %%
data = resp.json()

# %%
df = pd.DataFrame(data)
df
# Out:
#      number contract_name                    name                 address  \
# 0        42        dublin        SMITHFIELD NORTH        Smithfield North
# 1        30        dublin    PARNELL SQUARE NORTH    Parnell Square North
# 2        54        dublin          CLONMEL STREET          Clonmel Street
# 3       108        dublin           AVONDALE ROAD           Avondale Road
# 4        20        dublin       JAMES STREET EAST       James Street East
# ..      ...           ...                     ...                     ...
# 109      39        dublin          WILTON TERRACE          Wilton Terrace
# 110      83        dublin              EMMET ROAD              Emmet Road
# 111      92        dublin  HEUSTON BRIDGE (NORTH)  Heuston Bridge (North)
# 112      21        dublin   LEINSTER STREET SOUTH   Leinster Street South
# 113      88        dublin         BLACKHALL PLACE         Blackhall Place
#
#                                               position  banking  bonus  \
# ...

# %%
def convert_timestamp(t):
    timestamp_seconds = t/1000
    return datetime.datetime.fromtimestamp(timestamp_seconds).strftime('%Y-%m-%d %H:%M:%S')

# %%
df['last_update'] = df['last_update'].apply(convert_timestamp)

# %%
df
# Out:
#      number contract_name                    name                 address  \
# 0        42        dublin        SMITHFIELD NORTH        Smithfield North
# 1        30        dublin    PARNELL SQUARE NORTH    Parnell Square North
# 2        54        dublin          CLONMEL STREET          Clonmel Street
# 3       108        dublin           AVONDALE ROAD           Avondale Road
# 4        20        dublin       JAMES STREET EAST       James Street East
# ..      ...           ...                     ...                     ...
# 109      39        dublin          WILTON TERRACE          Wilton Terrace
# 110      83        dublin              EMMET ROAD              Emmet Road
# 111      92        dublin  HEUSTON BRIDGE (NORTH)  Heuston Bridge (North)
# 112      21        dublin   LEINSTER STREET SOUTH   Leinster Street South
# 113      88        dublin         BLACKHALL PLACE         Blackhall Place
#
#                                               position  banking  bonus  \
# ...

# %%
df['latitude'] = df['position'].apply(lambda x: x['lat'])
df['longitude'] = df['position'].apply(lambda x: x['lng'])

# %%
df
# Out:
#      number contract_name                    name                 address  \
# 0        42        dublin        SMITHFIELD NORTH        Smithfield North
# 1        30        dublin    PARNELL SQUARE NORTH    Parnell Square North
# 2        54        dublin          CLONMEL STREET          Clonmel Street
# 3       108        dublin           AVONDALE ROAD           Avondale Road
# 4        20        dublin       JAMES STREET EAST       James Street East
# ..      ...           ...                     ...                     ...
# 109      39        dublin          WILTON TERRACE          Wilton Terrace
# 110      83        dublin              EMMET ROAD              Emmet Road
# 111      92        dublin  HEUSTON BRIDGE (NORTH)  Heuston Bridge (North)
# 112      21        dublin   LEINSTER STREET SOUTH   Leinster Street South
# 113      88        dublin         BLACKHALL PLACE         Blackhall Place
#
#                                               position  banking  bonus  \
# ...

# %%
def reverse_geocode(lat, lng):
    url = f"https://nominatim.openstreetmap.org/reverse?lat={lat}&lon={lng}&format=json"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        return data.get('display_name')
    return None

# %%
#df['location_name'] = df.apply(lambda row: reverse_geocode(row['latitude'], row['longitude']), axis=1)

# %%
#df

# %%
import requests

def fetch_data(endpoint):
    print("Fetching data from the API...")
    response = requests.get(endpoint)
    if response.status_code == 200:
        print("Data fetched successfully.")
        return response.json()
    else:
        print(f"Error: Failed to fetch data. Status code: {response.status_code}")
        return None

# %%
def upload_to_azure_sql(data, connection_string, table_name):
    print("Uploading data to Azure SQL Server...")
    try:
        conn = odbc.connect(connection_string)
        cursor = conn.cursor()

        # Check if the table exists
        cursor.execute(f"SELECT 1 FROM INFORMATION_SCHEMA.TABLES WHERE TABLE_NAME = '{table_name}'")
        if not cursor.fetchone():
            # Create the table if it doesn't exist
            create_table_query = f"CREATE TABLE {table_name} ("
            create_table_query += ", ".join([f"{col} VARCHAR(MAX)" for col in data.columns])  # Assuming all columns are VARCHAR(MAX)
            create_table_query += ")"
            cursor.execute(create_table_query)
            print(f"Table '{table_name}' created successfully.")

        # Construct the SQL query with parameterized placeholders
        placeholders = ', '.join(['?' for _ in range(len(data.columns))])
        columns = ', '.join(data.columns)

        # Iterate over the rows in the DataFrame and execute the insert statement
        for _, row in data.iterrows():
            # Convert row values to the appropriate data types and then to a tuple
            values = tuple(row.astype(str))  # Convert all values to string
            cursor.execute(f"INSERT INTO {table_name} ({columns}) VALUES ({placeholders})", values)

        # Commit the transaction and close the cursor
        conn.commit()
        cursor.close()
        conn.close()
        
        print("Data uploaded successfully.")
    except Exception as e:
        print("Error occurred while uploading data:", e)

# %%
def fetch_and_upload_data(endpoint, connection_string, total_duration_minutes):
    end_time = time.time() + (total_duration_minutes * 60)
    while time.time() < end_time:
        data = fetch_data(endpoint)
        if data:
            df = pd.DataFrame(data)
            df['latitude'] = df['position'].apply(lambda x: x['lat'])
            df['longitude'] = df['position'].apply(lambda x: x['lng'])
            df['location_name'] = df.apply(lambda row: reverse_geocode(row['latitude'], row['longitude']), axis=1)
            df.drop('position', axis=1, inplace=True)
            upload_to_azure_sql(df, connection_string, "public_cycle_db_09_04_2024")
        print("Waiting for 20 minutes before fetching again...")
        time.sleep(1200)

# %%
connection_string = connection_string = "Driver={ODBC Driver 18 for SQL Server};Server=tcp:cycles.database.windows.net,1433;Database=dub_cycle_db;Uid={20014083@mydbs.ie};Pwd={wD3PP^;O};Encrypt=yes;TrustServerCertificate=no;Connection Timeout=30;Authentication=ActiveDirectoryPassword"
total_duration_minutes = 12 * 60  # Fetch data for 12 hours
fetch_and_upload_data(endpoint, connection_string, total_duration_minutes)
# Out:
# Fetching data from the API...
# Data fetched successfully.
# Uploading data to Azure SQL Server...
# Table 'public_cycle_db_09_04_2024' created successfully.
# Data uploaded successfully.
# Waiting for 20 minutes before fetching again...

# %%
import pyodbc
import pandas as pd

def read_from_azure_sql(connection_string, table_name):
    try:
        conn = odbc.connect(connection_string)
        cursor = conn.cursor()

        # Execute a select query to fetch data from the specified table
        cursor.execute(f"SELECT * FROM {table_name}")

        # Fetch all rows from the result set
        rows = cursor.fetchall()

        # Convert the fetched data into a pandas DataFrame
        df = pd.DataFrame(rows, columns=[column[0] for column in cursor.description])

        # Close the cursor and connection
        cursor.close()
        conn.close()

        return df
    except Exception as e:
        print("Error occurred while reading data:", e)


table_name = "public_cycle_db_09_04_2024"

ud = read_from_azure_sql(connection_string, table_name)
print(df)

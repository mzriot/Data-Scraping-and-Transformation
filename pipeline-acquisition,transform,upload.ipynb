# %% [markdown]
# ## Acquiring live data by API of Dublin Cycles and connecting it to mongodb

# %% [markdown]
# ### Loading required libraries

# %%
import requests
import json
import pandas as pd

# %%
#Defining API key
api_key = "9c31defb68c5ac281ef53ad13569fa29d295e408"

# %%
#Defining endpoint/url
endpoint = f"https://api.jcdecaux.com/vls/v1/stations?contract=dublin&apiKey={api_key}"

# %%
# Requesting to get the data through API link
resp = requests.get(endpoint)

# %%
# getting response [200], hence we are getting the live data from API
resp
# Out:
# <Response [200]>

# %%
#checking the content of our data fetched through API
resp.content
# Out:
# b'[{"number":42,"contract_name":"dublin","name":"SMITHFIELD NORTH","address":"Smithfield North","position":{"lat":53.349562,"lng":-6.278198},"banking":false,"bonus":false,"bike_stands":30,"available_bike_stands":27,"available_bikes":3,"status":"OPEN","last_update":1712839473000},{"number":30,"contract_name":"dublin","name":"PARNELL SQUARE NORTH","address":"Parnell Square North","position":{"lat":53.3537415547453,"lng":-6.26530144781526},"banking":false,"bonus":false,"bike_stands":20,"available_bike_stands":18,"available_bikes":1,"status":"OPEN","last_update":1712839506000},{"number":54,"contract_name":"dublin","name":"CLONMEL STREET","address":"Clonmel Street","position":{"lat":53.336021,"lng":-6.26298},"banking":false,"bonus":false,"bike_stands":33,"available_bike_stands":29,"available_bikes":4,"status":"OPEN","last_update":1712839542000},{"number":108,"contract_name":"dublin","name":"AVONDALE ROAD","address":"Avondale Road","position":{"lat":53.359405,"lng":-6.276142},"banking":false,"bonus":false,"bike_stands":35,"available_bike_stands":22,"available_bikes":13,"status":"OPEN","last_update":1712839422000},{"number":20,"contract_name":"dublin","name":"JAMES STREET EAST","address":"James Street East","position":{"lat":53.336597,"lng":-6.248109},"banking":false,"bonus":false,"bike_stands":30,"available_bike_stands":20,"available_bikes":10,"status":"OPEN","last_update":1712839561000},{"number":56,"contract_name":"dublin","name":"MOUNT STREET LOWER","address":"Mount Street Lower","position":{"lat":53.33796,"lng":-6.24153},"banking":false,"bonus":false,"bike_stands":40,"available_bike_stands":26,"available_bikes":14,"status":"OPEN","last_update":1712839553000},{"number":6,"contract_name":"dublin","name":"CHRISTCHURCH PLACE","address":"Christchurch Place","position":{"lat":53.343368,"lng":-6.27012},"banking":false,"bonus":false,"bike_stands":20,"available_bike_stands":20,"available_bikes":0,"status":"OPEN","last_update":1712839343000},{"number":18,"contract_name":"dublin","name":"GRANTHAM STREET","address":"Grantham Street","position":{"lat":53.334123,"lng":-6.265436},"banking":false,"bonus":false,"bike_stands":30,"available_bike_stands":29,"available_bikes":1,"status":"OPEN","last_update":1712839435000},{"number":32,"contract_name":"dublin","name":"PEARSE STREET","address":"Pearse Street","position":{"lat":53.344304,"lng":-6.250427},"banking":false,"bonus":false,"bike_stands":30,"available_bike_stands":18,"available_bikes":12,"status":"OPEN","last_update":1712839398000},{"number":52,"contract_name":"dublin","name":"YORK STREET EAST","address":"York Street East","position":{"lat":53.338755,"lng":-6.262003},"banking":false,"bonus":false,"bike_stands":32,"available_bike_stands":21,"available_bikes":11,"status":"OPEN","last_update":1712839413000},{"number":48,"contract_name":"dublin","name":"EXCISE WALK","address":"Excise Walk","position":{"lat":53.347777,"lng":-6.244239},"banking":false,"bonus":false,"bike_stands":40,"available_bike_stands":34,"available_bikes":6,"status":"OPEN","last_update":1712839552000},{"number":13,"contract_name":"dublin","name":"FITZWILLIAM SQUARE WEST","address":"Fitzwilliam Square West","position":{"lat":53.336074,"lng":-6.252825},"banking":false,"bonus":false,"bike_stands":30,"available_bike_stands":25,"available_bikes":5,"status":"OPEN","last_update":1712839405000},{"number":43,"contract_name":"dublin","name":"PORTOBELLO ROAD","address":"Portobello Road","position":{"lat":53.330091,"lng":-6.268044},"banking":false,"bonus":false,"bike_stands":30,"available_bike_stands":24,"available_bikes":6,"status":"OPEN","last_update":1712839450000},{"number":31,"contract_name":"dublin","name":"PARNELL STREET","address":"Parnell Street","position":{"lat":53.350929,"lng":-6.265125},"banking":false,"bonus":false,"bike_stands":20,"available_bike_stands":12,"available_bikes":8,"status":"OPEN","last_update":1712839448000},{"number":98,"contract_name":"dublin","name":"FREDERICK STREET SOUTH","address":"Frederick Street South", ...

# %%
#getting the data in json format
data = resp.json()

# %%
#converting the data into dataframe through pandas
df = pd.DataFrame(data)

# %%
df
# Out:
#      number contract_name                    name                 address  \
# 0        42        dublin        SMITHFIELD NORTH        Smithfield North
# 1        30        dublin    PARNELL SQUARE NORTH    Parnell Square North
# 2        54        dublin          CLONMEL STREET          Clonmel Street
# 3       108        dublin           AVONDALE ROAD           Avondale Road
# 4        20        dublin       JAMES STREET EAST       James Street East
# ..      ...           ...                     ...                     ...
# 109      39        dublin          WILTON TERRACE          Wilton Terrace
# 110      83        dublin              EMMET ROAD              Emmet Road
# 111      92        dublin  HEUSTON BRIDGE (NORTH)  Heuston Bridge (North)
# 112      21        dublin   LEINSTER STREET SOUTH   Leinster Street South
# 113      88        dublin         BLACKHALL PLACE         Blackhall Place
#
#                                               position  banking  bonus  \
# 0                 {'lat': 53.349562, 'lng': -6.278198}    False  False
# 1    {'lat': 53.3537415547453, 'lng': -6.2653014478...    False  False
# 2                  {'lat': 53.336021, 'lng': -6.26298}    False  False
# 3                 {'lat': 53.359405, 'lng': -6.276142}    False  False
# 4                 {'lat': 53.336597, 'lng': -6.248109}    False  False
# ..                                                 ...      ...    ...
# 109               {'lat': 53.332383, 'lng': -6.252717}    False  False
# 110               {'lat': 53.340714, 'lng': -6.308191}    False  False
# 111               {'lat': 53.347802, 'lng': -6.292432}    False  False
# 112                {'lat': 53.34218, 'lng': -6.254485}    False  False
# 113                 {'lat': 53.3488, 'lng': -6.281637}    False  False
#
#      bike_stands  available_bike_stands  available_bikes status    last_update
# 0             30                     27                3   OPEN  1712839473000
# 1             20                     18                1   OPEN  1712839506000
# 2             33                     29                4   OPEN  1712839542000
# 3             35                     22               13   OPEN  1712839422000
# 4             30                     20               10   OPEN  1712839561000
# ..           ...                    ...              ...    ...            ...
# 109           20                     20                0   OPEN  1712839496000
# 110           40                     31                9   OPEN  1712839465000
# 111           40                     36                4   OPEN  1712839445000
# 112           30                      9               21   OPEN  1712839467000
# 113           30                     27                3   OPEN  1712839429000
#
# [114 rows x 12 columns]

# %% [markdown]
# ### We can observe from the data that last_update time is a timestamp with time represented in milisecond, we will write a function to convert it into human readable format

# %%
#Defining a function to convert timestamp into data and time
from datetime import datetime

def time_stamp_convert(time_ms):
    time_s = time_ms/1000   #converting miliseconds time to seconds
    return datetime.fromtimestamp(time_s).strftime('%Y-%m-%d %H:%M:%S')

# %%
#appplying the conversion on last_update column
df['last_update'] = df['last_update'].apply(time_stamp_convert)

# %% [markdown]
# #### We can observe that the timestamp has been converted to human readable format

# %%
df
# Out:
#      number contract_name                    name                 address  \
# 0        42        dublin        SMITHFIELD NORTH        Smithfield North
# 1        30        dublin    PARNELL SQUARE NORTH    Parnell Square North
# 2        54        dublin          CLONMEL STREET          Clonmel Street
# 3       108        dublin           AVONDALE ROAD           Avondale Road
# 4        20        dublin       JAMES STREET EAST       James Street East
# ..      ...           ...                     ...                     ...
# 109      39        dublin          WILTON TERRACE          Wilton Terrace
# 110      83        dublin              EMMET ROAD              Emmet Road
# 111      92        dublin  HEUSTON BRIDGE (NORTH)  Heuston Bridge (North)
# 112      21        dublin   LEINSTER STREET SOUTH   Leinster Street South
# 113      88        dublin         BLACKHALL PLACE         Blackhall Place
#
#                                               position  banking  bonus  \
# 0                 {'lat': 53.349562, 'lng': -6.278198}    False  False
# 1    {'lat': 53.3537415547453, 'lng': -6.2653014478...    False  False
# 2                  {'lat': 53.336021, 'lng': -6.26298}    False  False
# 3                 {'lat': 53.359405, 'lng': -6.276142}    False  False
# 4                 {'lat': 53.336597, 'lng': -6.248109}    False  False
# ..                                                 ...      ...    ...
# 109               {'lat': 53.332383, 'lng': -6.252717}    False  False
# 110               {'lat': 53.340714, 'lng': -6.308191}    False  False
# 111               {'lat': 53.347802, 'lng': -6.292432}    False  False
# 112                {'lat': 53.34218, 'lng': -6.254485}    False  False
# 113                 {'lat': 53.3488, 'lng': -6.281637}    False  False
#
#      bike_stands  available_bike_stands  available_bikes status  \
# 0             30                     27                3   OPEN
# 1             20                     18                1   OPEN
# 2             33                     29                4   OPEN
# 3             35                     22               13   OPEN
# 4             30                     20               10   OPEN
# ..           ...                    ...              ...    ...
# 109           20                     20                0   OPEN
# 110           40                     31                9   OPEN
# 111           40                     36                4   OPEN
# 112           30                      9               21   OPEN
# 113           30                     27                3   OPEN
#
#              last_update
# 0    2024-04-11 13:44:33
# 1    2024-04-11 13:45:06
# 2    2024-04-11 13:45:42
# 3    2024-04-11 13:43:42
# 4    2024-04-11 13:46:01
# ..                   ...
# 109  2024-04-11 13:44:56
# 110  2024-04-11 13:44:25
# 111  2024-04-11 13:44:05
# 112  2024-04-11 13:44:27
# 113  2024-04-11 13:43:49
#
# [114 rows x 12 columns]

# %% [markdown]
# #### We can also observe that the position column is also in latitude and logitude. Hence converting them into human readable format

# %% [markdown]
# #### For this conversion we will be using Nominatim API : https://nominatim.org/release-docs/latest/api/Reverse/

# %%
#Splitting the position values and assigning it to two respective columns - latitude and longitude
df[['latitude', 'longitude']] = df['position'].apply(pd.Series)

# %%
df
# Out:
#      number contract_name                    name                 address  \
# 0        42        dublin        SMITHFIELD NORTH        Smithfield North
# 1        30        dublin    PARNELL SQUARE NORTH    Parnell Square North
# 2        54        dublin          CLONMEL STREET          Clonmel Street
# 3       108        dublin           AVONDALE ROAD           Avondale Road
# 4        20        dublin       JAMES STREET EAST       James Street East
# ..      ...           ...                     ...                     ...
# 109      39        dublin          WILTON TERRACE          Wilton Terrace
# 110      83        dublin              EMMET ROAD              Emmet Road
# 111      92        dublin  HEUSTON BRIDGE (NORTH)  Heuston Bridge (North)
# 112      21        dublin   LEINSTER STREET SOUTH   Leinster Street South
# 113      88        dublin         BLACKHALL PLACE         Blackhall Place
#
#                                               position  banking  bonus  \
# 0                 {'lat': 53.349562, 'lng': -6.278198}    False  False
# 1    {'lat': 53.3537415547453, 'lng': -6.2653014478...    False  False
# 2                  {'lat': 53.336021, 'lng': -6.26298}    False  False
# 3                 {'lat': 53.359405, 'lng': -6.276142}    False  False
# 4                 {'lat': 53.336597, 'lng': -6.248109}    False  False
# ..                                                 ...      ...    ...
# 109               {'lat': 53.332383, 'lng': -6.252717}    False  False
# 110               {'lat': 53.340714, 'lng': -6.308191}    False  False
# 111               {'lat': 53.347802, 'lng': -6.292432}    False  False
# 112                {'lat': 53.34218, 'lng': -6.254485}    False  False
# 113                 {'lat': 53.3488, 'lng': -6.281637}    False  False
#
#      bike_stands  available_bike_stands  available_bikes status  \
# 0             30                     27                3   OPEN
# 1             20                     18                1   OPEN
# 2             33                     29                4   OPEN
# 3             35                     22               13   OPEN
# 4             30                     20               10   OPEN
# ..           ...                    ...              ...    ...
# 109           20                     20                0   OPEN
# 110           40                     31                9   OPEN
# 111           40                     36                4   OPEN
# 112           30                      9               21   OPEN
# 113           30                     27                3   OPEN
#
#              last_update   latitude  longitude
# 0    2024-04-11 13:44:33  53.349562  -6.278198
# 1    2024-04-11 13:45:06  53.353742  -6.265301
# 2    2024-04-11 13:45:42  53.336021  -6.262980
# 3    2024-04-11 13:43:42  53.359405  -6.276142
# 4    2024-04-11 13:46:01  53.336597  -6.248109
# ..                   ...        ...        ...
# 109  2024-04-11 13:44:56  53.332383  -6.252717
# 110  2024-04-11 13:44:25  53.340714  -6.308191
# 111  2024-04-11 13:44:05  53.347802  -6.292432
# 112  2024-04-11 13:44:27  53.342180  -6.254485
# 113  2024-04-11 13:43:49  53.348800  -6.281637
#
# [114 rows x 14 columns]

# %% [markdown]
# #### Writing a function to reverse geocode from latitude and longitude to a human readable address

# %%
def reverse_geocode(lat, lng):
    Nominatim_url = f"https://nominatim.openstreetmap.org/reverse?lat={lat}&lon={lng}&format=json"
    response = requests.get(Nominatim_url)
    data = response.json()
    return data.get('display_name')

# %%
df['position_address'] = df.apply(lambda row: reverse_geocode(row['latitude'], row['longitude']), axis=1)

# %% [markdown]
# ### We can observe below that the postion column has been converted into exact address extracted from coordinates and reversed geo to readable format

# %%
df
# Out:
#      number contract_name                    name                 address  \
# 0        42        dublin        SMITHFIELD NORTH        Smithfield North
# 1        30        dublin    PARNELL SQUARE NORTH    Parnell Square North
# 2        54        dublin          CLONMEL STREET          Clonmel Street
# 3       108        dublin           AVONDALE ROAD           Avondale Road
# 4        20        dublin       JAMES STREET EAST       James Street East
# ..      ...           ...                     ...                     ...
# 109      39        dublin          WILTON TERRACE          Wilton Terrace
# 110      83        dublin              EMMET ROAD              Emmet Road
# 111      92        dublin  HEUSTON BRIDGE (NORTH)  Heuston Bridge (North)
# 112      21        dublin   LEINSTER STREET SOUTH   Leinster Street South
# 113      88        dublin         BLACKHALL PLACE         Blackhall Place
#
#                                               position  banking  bonus  \
# 0                 {'lat': 53.349562, 'lng': -6.278198}    False  False
# 1    {'lat': 53.3537415547453, 'lng': -6.2653014478...    False  False
# 2                  {'lat': 53.336021, 'lng': -6.26298}    False  False
# 3                 {'lat': 53.359405, 'lng': -6.276142}    False  False
# 4                 {'lat': 53.336597, 'lng': -6.248109}    False  False
# ..                                                 ...      ...    ...
# 109               {'lat': 53.332383, 'lng': -6.252717}    False  False
# 110               {'lat': 53.340714, 'lng': -6.308191}    False  False
# 111               {'lat': 53.347802, 'lng': -6.292432}    False  False
# 112                {'lat': 53.34218, 'lng': -6.254485}    False  False
# 113                 {'lat': 53.3488, 'lng': -6.281637}    False  False
#
#      bike_stands  available_bike_stands  available_bikes status  \
# 0             30                     27                3   OPEN
# 1             20                     18                1   OPEN
# 2             33                     29                4   OPEN
# 3             35                     22               13   OPEN
# 4             30                     20               10   OPEN
# ..           ...                    ...              ...    ...
# 109           20                     20                0   OPEN
# 110           40                     31                9   OPEN
# 111           40                     36                4   OPEN
# 112           30                      9               21   OPEN
# 113           30                     27                3   OPEN
#
#              last_update   latitude  longitude  \
# 0    2024-04-11 13:44:33  53.349562  -6.278198
# 1    2024-04-11 13:45:06  53.353742  -6.265301
# 2    2024-04-11 13:45:42  53.336021  -6.262980
# 3    2024-04-11 13:43:42  53.359405  -6.276142
# 4    2024-04-11 13:46:01  53.336597  -6.248109
# ..                   ...        ...        ...
# 109  2024-04-11 13:44:56  53.332383  -6.252717
# 110  2024-04-11 13:44:25  53.340714  -6.308191
# 111  2024-04-11 13:44:05  53.347802  -6.292432
# 112  2024-04-11 13:44:27  53.342180  -6.254485
# 113  2024-04-11 13:43:49  53.348800  -6.281637
#
#                                       position_address
# 0    Smithfield, Arran Quay C ED, Dublin, County Du...
# 1    Parnell Square North, Rotunda B Ward 1986, Dub...
# 2    Harcourt Creche, 1, Clonmel Street, Saint Kevi...
# 3    Avondale Road, Arran Quay A ED, Dublin, County...
# 4    49, Baggot Street Lower, South Dock ED, Dublin...
# ..                                                 ...
# 109  Wilton Terrace, South Dock ED, Dublin, County ...
# 110  Emmet Road, Kilmainham C Ward 1986, Dublin, Co...
# 111  Parkgate Street, Islandbridge, Phoenix Park ED...
# 112  Leinster Street South, Mansion House A Ward 19...
# 113  Blackhall, Blackhall Street, Smithfield, Arran...
#
# [114 rows x 15 columns]

# %%
#pruning columns not needed
df = df.drop(columns=["position","banking","bonus","latitude","longitude"])

# %%
df
# Out:
#      number contract_name                    name                 address  \
# 0        42        dublin        SMITHFIELD NORTH        Smithfield North
# 1        30        dublin    PARNELL SQUARE NORTH    Parnell Square North
# 2        54        dublin          CLONMEL STREET          Clonmel Street
# 3       108        dublin           AVONDALE ROAD           Avondale Road
# 4        20        dublin       JAMES STREET EAST       James Street East
# ..      ...           ...                     ...                     ...
# 109      39        dublin          WILTON TERRACE          Wilton Terrace
# 110      83        dublin              EMMET ROAD              Emmet Road
# 111      92        dublin  HEUSTON BRIDGE (NORTH)  Heuston Bridge (North)
# 112      21        dublin   LEINSTER STREET SOUTH   Leinster Street South
# 113      88        dublin         BLACKHALL PLACE         Blackhall Place
#
#      bike_stands  available_bike_stands  available_bikes status  \
# 0             30                     27                3   OPEN
# 1             20                     18                1   OPEN
# 2             33                     29                4   OPEN
# 3             35                     22               13   OPEN
# 4             30                     20               10   OPEN
# ..           ...                    ...              ...    ...
# 109           20                     20                0   OPEN
# 110           40                     31                9   OPEN
# 111           40                     36                4   OPEN
# 112           30                      9               21   OPEN
# 113           30                     27                3   OPEN
#
#              last_update                                   position_address
# 0    2024-04-11 13:44:33  Smithfield, Arran Quay C ED, Dublin, County Du...
# 1    2024-04-11 13:45:06  Parnell Square North, Rotunda B Ward 1986, Dub...
# 2    2024-04-11 13:45:42  Harcourt Creche, 1, Clonmel Street, Saint Kevi...
# 3    2024-04-11 13:43:42  Avondale Road, Arran Quay A ED, Dublin, County...
# 4    2024-04-11 13:46:01  49, Baggot Street Lower, South Dock ED, Dublin...
# ..                   ...                                                ...
# 109  2024-04-11 13:44:56  Wilton Terrace, South Dock ED, Dublin, County ...
# 110  2024-04-11 13:44:25  Emmet Road, Kilmainham C Ward 1986, Dublin, Co...
# 111  2024-04-11 13:44:05  Parkgate Street, Islandbridge, Phoenix Park ED...
# 112  2024-04-11 13:44:27  Leinster Street South, Mansion House A Ward 19...
# 113  2024-04-11 13:43:49  Blackhall, Blackhall Street, Smithfield, Arran...
#
# [114 rows x 10 columns]

# %% [markdown]
# ## Uploading the data to mongodb server

# %%
import pymongo
client = pymongo.MongoClient("mongodb+srv://20014083:Ya4MdlP2d1SPOkPr@cluster-cycles.icvwll2.mongodb.net/?retryWrites=true&w=majority&appName=Cluster-cycles")
db = client["mydata"]
collection=db['listings']

# %%
print(client.list_database_names())
# Out:
# ['sample_mflix', 'admin', 'local']

# %% [markdown]
# #### Converting the data frame to dictionary, appropriate format for mongo db server

# %%
data_dic = df.to_dict(orient='records')
collection.insert_many(data_dic)
# Out:
# InsertManyResult([ObjectId('6617dbf14a7d0d8ef6249c38'), ObjectId('6617dbf14a7d0d8ef6249c39'), ObjectId('6617dbf14a7d0d8ef6249c3a'), ObjectId('6617dbf14a7d0d8ef6249c3b'), ObjectId('6617dbf14a7d0d8ef6249c3c'), ObjectId('6617dbf14a7d0d8ef6249c3d'), ObjectId('6617dbf14a7d0d8ef6249c3e'), ObjectId('6617dbf14a7d0d8ef6249c3f'), ObjectId('6617dbf14a7d0d8ef6249c40'), ObjectId('6617dbf14a7d0d8ef6249c41'), ObjectId('6617dbf14a7d0d8ef6249c42'), ObjectId('6617dbf14a7d0d8ef6249c43'), ObjectId('6617dbf14a7d0d8ef6249c44'), ObjectId('6617dbf14a7d0d8ef6249c45'), ObjectId('6617dbf14a7d0d8ef6249c46'), ObjectId('6617dbf14a7d0d8ef6249c47'), ObjectId('6617dbf14a7d0d8ef6249c48'), ObjectId('6617dbf14a7d0d8ef6249c49'), ObjectId('6617dbf14a7d0d8ef6249c4a'), ObjectId('6617dbf14a7d0d8ef6249c4b'), ObjectId('6617dbf14a7d0d8ef6249c4c'), ObjectId('6617dbf14a7d0d8ef6249c4d'), ObjectId('6617dbf14a7d0d8ef6249c4e'), ObjectId('6617dbf14a7d0d8ef6249c4f'), ObjectId('6617dbf14a7d0d8ef6249c50'), ObjectId('6617dbf14a7d0d8ef6249c51'), ObjectId('6617dbf14a7d0d8ef6249c52'), ObjectId('6617dbf14a7d0d8ef6249c53'), ObjectId('6617dbf14a7d0d8ef6249c54'), ObjectId('6617dbf14a7d0d8ef6249c55'), ObjectId('6617dbf14a7d0d8ef6249c56'), ObjectId('6617dbf14a7d0d8ef6249c57'), ObjectId('6617dbf14a7d0d8ef6249c58'), ObjectId('6617dbf14a7d0d8ef6249c59'), ObjectId('6617dbf14a7d0d8ef6249c5a'), ObjectId('6617dbf14a7d0d8ef6249c5b'), ObjectId('6617dbf14a7d0d8ef6249c5c'), ObjectId('6617dbf14a7d0d8ef6249c5d'), ObjectId('6617dbf14a7d0d8ef6249c5e'), ObjectId('6617dbf14a7d0d8ef6249c5f'), ObjectId('6617dbf14a7d0d8ef6249c60'), ObjectId('6617dbf14a7d0d8ef6249c61'), ObjectId('6617dbf14a7d0d8ef6249c62'), ObjectId('6617dbf14a7d0d8ef6249c63'), ObjectId('6617dbf14a7d0d8ef6249c64'), ObjectId('6617dbf14a7d0d8ef6249c65'), ObjectId('6617dbf14a7d0d8ef6249c66'), ObjectId('6617dbf14a7d0d8ef6249c67'), ObjectId('6617dbf14a7d0d8ef6249c68'), ObjectId('6617dbf14a7d0d8ef6249c69'), ObjectId('6617dbf14a7d0d8ef6249c6a'), ObjectId('6617dbf14a7d0d8ef6249c6b'), ObjectId('6617dbf14a7d0d8ef6249c6c'), ObjectId('6617dbf14a7d0d8ef6249c6d'), ObjectId('6617dbf14a7d0d8ef6249c6e'), ObjectId('6617dbf14a7d0d8ef6249c6f'), ObjectId('6617dbf14a7d0d8ef6249c70'), ObjectId('6617dbf14a7d0d8ef6249c71'), ObjectId('6617dbf14a7d0d8ef6249c72'), ObjectId('6617dbf14a7d0d8ef6249c73'), ObjectId('6617dbf14a7d0d8ef6249c74'), ObjectId('6617dbf14a7d0d8ef6249c75'), ObjectId('6617dbf14a7d0d8ef6249c76'), ObjectId('6617dbf14a7d0d8ef6249c77'), ObjectId('6617dbf14a7d0d8ef6249c78'), ObjectId('6617dbf14a7d0d8ef6249c79'), ObjectId('6617dbf14a7d0d8ef6249c7a'), ObjectId('6617dbf14a7d0d8ef6249c7b'), ObjectId('6617dbf14a7d0d8ef6249c7c'), ObjectId('6617dbf14a7d0d8ef6249c7d'), ObjectId('6617dbf14a7d0d8ef6249c7e'), ObjectId('6617dbf14a7d0d8ef6249c7f'), ObjectId('6617dbf14a7d0d8ef6249c80'), ObjectId('6617dbf14a7d0d8ef6249c81'), ObjectId('6617dbf14a7d0d8ef6249c82'), ObjectId('6617dbf14a7d0d8ef6249c83'), ObjectId('6617dbf14a7d0d8ef6249c84'), ObjectId('6617dbf14a7d0d8ef6249c85'), ObjectId('6617dbf14a7d0d8ef6249c86'), ObjectId('6617dbf14a7d0d8ef6249c87'), ObjectId('6617dbf14a7d0d8ef6249c88'), ObjectId('6617dbf14a7d0d8ef6249c89'), ObjectId('6617dbf14a7d0d8ef6249c8a'), ObjectId('6617dbf14a7d0d8ef6249c8b'), ObjectId('6617dbf14a7d0d8ef6249c8c'), ObjectId('6617dbf14a7d0d8ef6249c8d'), ObjectId('6617dbf14a7d0d8ef6249c8e'), ObjectId('6617dbf14a7d0d8ef6249c8f'), ObjectId('6617dbf14a7d0d8ef6249c90'), ObjectId('6617dbf14a7d0d8ef6249c91'), ObjectId('6617dbf14a7d0d8ef6249c92'), ObjectId('6617dbf14a7d0d8ef6249c93'), ObjectId('6617dbf14a7d0d8ef6249c94'), ObjectId('6617dbf14a7d0d8ef6249c95'), ObjectId('6617dbf14a7d0d8ef6249c96'), ObjectId('6617dbf14a7d0d8ef6249c97'), ObjectId('6617dbf14a7d0d8ef6249c98'), ObjectId('6617dbf14a7d0d8ef6249c99'), ObjectId('6617dbf14a7d0d8ef6249c9a'), ObjectId('6617dbf14a7d0d8ef6249c9b'), ObjectId('6617dbf14a7d0d8ef6249c9c'), ObjectId('6617dbf14a7d0d8ef6249c9d'), ObjectId('6617dbf14a7d0d8ef6249c9e'), ObjectId('6617dbf14a7d0d8ef6249c9f'), ObjectId('6617dbf14a7d0d8ef624 ...

# %% [markdown]
# #### Fetching the data back and checking if the data is inserted properly

# %%
cursor = collection.find()
for document in cursor:
    print(document)
# Out:
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c38'), 'number': 42, 'contract_name': 'dublin', 'name': 'SMITHFIELD NORTH', 'address': 'Smithfield North', 'bike_stands': 30, 'available_bike_stands': 27, 'available_bikes': 3, 'status': 'OPEN', 'last_update': '2024-04-11 13:44:33', 'position_address': 'Smithfield, Arran Quay C ED, Dublin, County Dublin, Leinster, D07 WR63, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c39'), 'number': 30, 'contract_name': 'dublin', 'name': 'PARNELL SQUARE NORTH', 'address': 'Parnell Square North', 'bike_stands': 20, 'available_bike_stands': 18, 'available_bikes': 1, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:06', 'position_address': 'Parnell Square North, Rotunda B Ward 1986, Dublin, County Dublin, Leinster, D01 E7C1, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c3a'), 'number': 54, 'contract_name': 'dublin', 'name': 'CLONMEL STREET', 'address': 'Clonmel Street', 'bike_stands': 33, 'available_bike_stands': 29, 'available_bikes': 4, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:42', 'position_address': 'Harcourt Creche, 1, Clonmel Street, Saint Kevins Ward 1986, Dublin, County Dublin, Leinster, D02 NX65, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c3b'), 'number': 108, 'contract_name': 'dublin', 'name': 'AVONDALE ROAD', 'address': 'Avondale Road', 'bike_stands': 35, 'available_bike_stands': 22, 'available_bikes': 13, 'status': 'OPEN', 'last_update': '2024-04-11 13:43:42', 'position_address': 'Avondale Road, Arran Quay A ED, Dublin, County Dublin, Leinster, D07 ED7R, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c3c'), 'number': 20, 'contract_name': 'dublin', 'name': 'JAMES STREET EAST', 'address': 'James Street East', 'bike_stands': 30, 'available_bike_stands': 20, 'available_bikes': 10, 'status': 'OPEN', 'last_update': '2024-04-11 13:46:01', 'position_address': '49, Baggot Street Lower, South Dock ED, Dublin, County Dublin, Leinster, D02 YC83, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c3d'), 'number': 56, 'contract_name': 'dublin', 'name': 'MOUNT STREET LOWER', 'address': 'Mount Street Lower', 'bike_stands': 40, 'available_bike_stands': 26, 'available_bikes': 14, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:53', 'position_address': 'Ferry House, 48-53, Mount Street Lower, South Dock ED, Dublin, County Dublin, Leinster, D02 HD59, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c3e'), 'number': 6, 'contract_name': 'dublin', 'name': 'CHRISTCHURCH PLACE', 'address': 'Christchurch Place', 'bike_stands': 20, 'available_bike_stands': 20, 'available_bikes': 0, 'status': 'OPEN', 'last_update': '2024-04-11 13:42:23', 'position_address': 'Bull & Castle, 5-7, Christchurch Place, Royal Exchange A ED, Dublin, Dublin 2, Leinster, D02 RH33, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c3f'), 'number': 18, 'contract_name': 'dublin', 'name': 'GRANTHAM STREET', 'address': 'Grantham Street', 'bike_stands': 30, 'available_bike_stands': 29, 'available_bikes': 1, 'status': 'OPEN', 'last_update': '2024-04-11 13:43:55', 'position_address': "Key Assets, Grantham Street, The Liberties, Saint Kevin's ED, Dublin, Dublin 2, Leinster, D08 W8HD, Éire / Ireland"}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c40'), 'number': 32, 'contract_name': 'dublin', 'name': 'PEARSE STREET', 'address': 'Pearse Street', 'bike_stands': 30, 'available_bike_stands': 18, 'available_bikes': 12, 'status': 'OPEN', 'last_update': '2024-04-11 13:43:18', 'position_address': 'The Academy, 42, Pearse Street, Mansion House A Ward 1986, Dublin, County Dublin, Leinster, D02 FP30, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c41'), 'number': 52, 'contract_name': 'dublin', 'name': 'YORK STREET EAST', 'address': 'York Street East', 'bike_stands': 32, 'available_bike_stands': 21, 'available_bikes': 11, 'status': 'OPEN', 'last_update': '2024-04-11 13:43:33', 'position_address': 'York House, 31A, York Street, Royal Exchange B Ward 1986, Dublin, County Dublin, Leinster, D02 RD40, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c42'), 'number': 48, 'contract_name': 'dublin', 'name': 'EXCISE WALK', 'address': 'Excise Walk', 'bike_stands': 40, 'available_bike_stands': 34, 'available_bikes': 6, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:52', 'position_address': 'Citibank, 1, North Wall Quay, North Dock C ED, Dublin, County Dublin, Leinster, D01 T8Y1, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c43'), 'number': 13, 'contract_name': 'dublin', 'name': 'FITZWILLIAM SQUARE WEST', 'address': 'Fitzwilliam Square West', 'bike_stands': 30, 'available_bike_stands': 25, 'available_bikes': 5, 'status': 'OPEN', 'last_update': '2024-04-11 13:43:25', 'position_address': '49, Fitzwilliam Square West, Mansion House B Ward 1986, Dublin, County Dublin, Leinster, D02 T922, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c44'), 'number': 43, 'contract_name': 'dublin', 'name': 'PORTOBELLO ROAD', 'address': 'Portobello Road', 'bike_stands': 30, 'available_bike_stands': 24, 'available_bikes': 6, 'status': 'OPEN', 'last_update': '2024-04-11 13:44:10', 'position_address': "44, Martin Street, Portobello, Saint Kevin's ED, Dublin, County Dublin, Leinster, D08 E0C0, Éire / Ireland"}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c45'), 'number': 31, 'contract_name': 'dublin', 'name': 'PARNELL STREET', 'address': 'Parnell Street', 'bike_stands': 20, 'available_bike_stands': 12, 'available_bikes': 8, 'status': 'OPEN', 'last_update': '2024-04-11 13:44:08', 'position_address': 'Parnell Street, Rotunda B Ward 1986, Dublin, County Dublin, Leinster, D01 H578, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c46'), 'number': 98, 'contract_name': 'dublin', 'name': 'FREDERICK STREET SOUTH', 'address': 'Frederick Street South', 'bike_stands': 40, 'available_bike_stands': 25, 'available_bikes': 15, 'status': 'OPEN', 'last_update': '2024-04-11 13:43:37', 'position_address': '3-4, South Frederick Street, Mansion House B Ward 1986, Dublin, County Dublin, Leinster, D02 RF29, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c47'), 'number': 14, 'contract_name': 'dublin', 'name': 'FOWNES STREET UPPER', 'address': 'Fownes Street Upper', 'bike_stands': 30, 'available_bike_stands': 10, 'available_bikes': 20, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:40', 'position_address': 'Temple Bar, Exchange Street Upper, Temple Bar, Royal Exchange A Ward 1986, Dublin, County Dublin, Leinster, D08 N592, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c48'), 'number': 1, 'contract_name': 'dublin', 'name': 'CLARENDON ROW', 'address': 'Clarendon Row', 'bike_stands': 31, 'available_bike_stands': 6, 'available_bikes': 25, 'status': 'OPEN', 'last_update': '2024-04-11 13:42:10', 'position_address': 'TU Dublin - Conservatory of Music and Drama, Chatham Row, Royal Exchange B ED, Dublin, County Dublin, Leinster, D02 HX66, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c49'), 'number': 23, 'contract_name': 'dublin', 'name': 'CUSTOM HOUSE', 'address': 'Custom House', 'bike_stands': 30, 'available_bike_stands': 24, 'available_bikes': 6, 'status': 'OPEN', 'last_update': '2024-04-11 13:44:46', 'position_address': "Loopline Bridge, George's Quay, Mansion House A Ward 1986, Dublin, County Dublin, Leinster, D02 YY95, Éire / Ireland"}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c4a'), 'number': 106, 'contract_name': 'dublin', 'name': 'RATHDOWN ROAD', 'address': 'Rathdown Road', 'bike_stands': 40, 'available_bike_stands': 34, 'available_bikes': 6, 'status': 'OPEN', 'last_update': '2024-04-11 13:41:52', 'position_address': 'Rathdown Road, Grangegorman, Arran Quay B ED, Dublin, County Dublin, Leinster, D07 DT61, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c4b'), 'number': 112, 'contract_name': 'dublin', 'name': "NORTH CIRCULAR ROAD (O'CONNELL'S)", 'address': "North Circular Road (O'Connell's)", 'bike_stands': 30, 'available_bike_stands': 30, 'available_bikes': 0, 'status': 'OPEN', 'last_update': '2024-04-11 13:42:53', 'position_address': "O'Connell Secondary School, North Richmond Street, Ballybough B Ward 1986, Dublin, County Dublin, Leinster, D01 WY49, Éire / Ireland"}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c4c'), 'number': 68, 'contract_name': 'dublin', 'name': 'HANOVER QUAY', 'address': 'Hanover Quay', 'bike_stands': 40, 'available_bike_stands': 28, 'available_bikes': 12, 'status': 'OPEN', 'last_update': '2024-04-11 13:44:48', 'position_address': 'Hanover Quay, Dublin Docklands, South Dock ED, Dublin, County Dublin, Leinster, D02 E295, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c4d'), 'number': 74, 'contract_name': 'dublin', 'name': 'OLIVER BOND STREET', 'address': 'Oliver Bond Street', 'bike_stands': 30, 'available_bike_stands': 24, 'available_bikes': 6, 'status': 'OPEN', 'last_update': '2024-04-11 13:44:53', 'position_address': 'Oliver Bond Street, Merchants Quay A Ward 1986, Dublin, County Dublin, Leinster, D08 P8H3, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c4e'), 'number': 87, 'contract_name': 'dublin', 'name': 'COLLINS BARRACKS MUSEUM', 'address': 'Collins Barracks Museum', 'bike_stands': 38, 'available_bike_stands': 15, 'available_bikes': 23, 'status': 'OPEN', 'last_update': '2024-04-11 13:42:51', 'position_address': 'Liffey Street West, Arran Quay C Ward 1986, Dublin, County Dublin, Leinster, D07 A0F5, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c4f'), 'number': 84, 'contract_name': 'dublin', 'name': 'BROOKFIELD ROAD', 'address': 'Brookfield Road', 'bike_stands': 30, 'available_bike_stands': 20, 'available_bikes': 10, 'status': 'OPEN', 'last_update': '2024-04-11 13:44:39', 'position_address': 'Mace, 578, South Circular Road, Ushers F Ward 1986, Dublin, County Dublin, Leinster, D08 EP8E, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c50'), 'number': 90, 'contract_name': 'dublin', 'name': 'BENSON STREET', 'address': 'Benson Street', 'bike_stands': 40, 'available_bike_stands': 4, 'available_bikes': 36, 'status': 'OPEN', 'last_update': '2024-04-11 13:44:17', 'position_address': 'Accenture The Dock, 7, Hanover Quay, Dublin Docklands, South Dock ED, Dublin, County Dublin, Leinster, D02 DP23, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c51'), 'number': 11, 'contract_name': 'dublin', 'name': 'EARLSFORT TERRACE', 'address': 'Earlsfort Terrace', 'bike_stands': 30, 'available_bike_stands': 12, 'available_bikes': 18, 'status': 'OPEN', 'last_update': '2024-04-11 13:41:24', 'position_address': 'Earlsfort Terrace, Saint Kevins Ward 1986, Dublin, County Dublin, Leinster, D02 K710, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c52'), 'number': 17, 'contract_name': 'dublin', 'name': 'GOLDEN LANE', 'address': 'Golden Lane', 'bike_stands': 20, 'available_bike_stands': 12, 'available_bikes': 8, 'status': 'OPEN', 'last_update': '2024-04-11 13:43:50', 'position_address': 'GE Money, 31-36, Golden Lane, Royal Exchange A ED, Dublin, County Dublin, Leinster, D08 A5RV, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c53'), 'number': 45, 'contract_name': 'dublin', 'name': 'DEVERELL PLACE', 'address': 'Deverell Place', 'bike_stands': 30, 'available_bike_stands': 29, 'available_bikes': 1, 'status': 'OPEN', 'last_update': '2024-04-11 13:43:35', 'position_address': 'Deverell Place, North City Ward 1986, Dublin, County Dublin, Leinster, D01 KC83, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c54'), 'number': 114, 'contract_name': 'dublin', 'name': 'WILTON TERRACE (PARK)', 'address': 'Wilton Terrace (Park)', 'bike_stands': 40, 'available_bike_stands': 15, 'available_bikes': 25, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:45', 'position_address': 'Wilton Terrace (Park), Wilton Terrace, South Dock ED, Dublin, County Dublin, Leinster, D04 WN52, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c55'), 'number': 72, 'contract_name': 'dublin', 'name': 'JOHN STREET WEST', 'address': 'John Street West', 'bike_stands': 31, 'available_bike_stands': 25, 'available_bikes': 6, 'status': 'OPEN', 'last_update': '2024-04-11 13:43:50', 'position_address': 'John Street West, Merchants Quay A Ward 1986, Dublin, County Dublin, Leinster, D08 V0R1, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c56'), 'number': 63, 'contract_name': 'dublin', 'name': 'FENIAN STREET', 'address': 'Fenian Street', 'bike_stands': 35, 'available_bike_stands': 32, 'available_bikes': 3, 'status': 'OPEN', 'last_update': '2024-04-11 13:44:58', 'position_address': 'Hibernia College Dublin, 9-10, Fenian Street, Mansion House A ED, Dublin, County Dublin, Leinster, D02 KD51, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c57'), 'number': 113, 'contract_name': 'dublin', 'name': 'MERRION SQUARE SOUTH', 'address': 'Merrion Square South', 'bike_stands': 40, 'available_bike_stands': 33, 'available_bikes': 7, 'status': 'OPEN', 'last_update': '2024-04-11 13:44:09', 'position_address': 'dublinbikes, Merrion Square South, Mansion House B Ward 1986, Dublin, County Dublin, Leinster, D01 VY60, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c58'), 'number': 91, 'contract_name': 'dublin', 'name': 'SOUTH DOCK ROAD', 'address': 'South Dock Road', 'bike_stands': 30, 'available_bike_stands': 23, 'available_bikes': 7, 'status': 'OPEN', 'last_update': '2024-04-11 13:42:31', 'position_address': 'dublinbikes, South Dock Road, Dublin Docklands, Ballsbridge, South Dock Ward 1986, Dublin, County Dublin, Leinster, D04 K743, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c59'), 'number': 99, 'contract_name': 'dublin', 'name': 'CITY QUAY', 'address': 'City Quay', 'bike_stands': 30, 'available_bike_stands': 14, 'available_bikes': 16, 'status': 'OPEN', 'last_update': '2024-04-11 13:44:41', 'position_address': "Sir John Rogerson's Quay, Mansion House A Ward 1986, Dublin, County Dublin, Leinster, D02 Y773, Éire / Ireland"}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c5a'), 'number': 9, 'contract_name': 'dublin', 'name': 'EXCHEQUER STREET', 'address': 'Exchequer Street', 'bike_stands': 24, 'available_bike_stands': 12, 'available_bikes': 12, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:19', 'position_address': 'Ukiyo Bar, 7-9, Exchequer Street, Royal Exchange A Ward 1986, Dublin, County Dublin, Leinster, D02 VH59, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c5b'), 'number': 67, 'contract_name': 'dublin', 'name': 'THE POINT', 'address': 'The Point', 'bike_stands': 40, 'available_bike_stands': 36, 'available_bikes': 4, 'status': 'OPEN', 'last_update': '2024-04-11 13:43:52', 'position_address': 'North Wall Quay, North Wall, North Dock B Ward 1986, Dublin, County Dublin, Leinster, D01 V4A3, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c5c'), 'number': 116, 'contract_name': 'dublin', 'name': 'BROADSTONE', 'address': 'Broadstone', 'bike_stands': 30, 'available_bike_stands': 11, 'available_bikes': 19, 'status': 'OPEN', 'last_update': '2024-04-11 13:43:31', 'position_address': 'Dominick Street Upper, Inns Quay B Ward 1986, Dublin, County Dublin, Leinster, D07 X923, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c5d'), 'number': 55, 'contract_name': 'dublin', 'name': 'HATCH STREET', 'address': 'Hatch Street', 'bike_stands': 36, 'available_bike_stands': 7, 'available_bikes': 29, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:35', 'position_address': 'dublinbikes, Hatch Street Upper, Saint Kevins Ward 1986, Dublin, County Dublin, Leinster, D02 T380, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c5e'), 'number': 62, 'contract_name': 'dublin', 'name': 'LIME STREET', 'address': 'Lime Street', 'bike_stands': 40, 'available_bike_stands': 15, 'available_bikes': 25, 'status': 'OPEN', 'last_update': '2024-04-11 13:42:44', 'position_address': 'Block A, Lime Street, South Dock ED, Dublin, County Dublin, Leinster, D02 WY65, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c5f'), 'number': 5, 'contract_name': 'dublin', 'name': 'CHARLEMONT PLACE', 'address': 'Charlemont Street', 'bike_stands': 40, 'available_bike_stands': 23, 'available_bikes': 17, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:28', 'position_address': 'WeWork, 2, Charlemont Place, Saint Kevins Ward 1986, Dublin, County Dublin, Leinster, D02 WV10, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c60'), 'number': 97, 'contract_name': 'dublin', 'name': 'KILMAINHAM GAOL', 'address': 'Kilmainham Gaol', 'bike_stands': 40, 'available_bike_stands': 29, 'available_bikes': 11, 'status': 'OPEN', 'last_update': '2024-04-11 13:43:07', 'position_address': 'Dublin Food Co-op, Inchicore Road, Kilmainham B ED, Dublin, County Dublin, Leinster, D08 RK28, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c61'), 'number': 61, 'contract_name': 'dublin', 'name': 'HARDWICKE PLACE', 'address': 'Hardwicke Place', 'bike_stands': 25, 'available_bike_stands': 23, 'available_bikes': 2, 'status': 'OPEN', 'last_update': '2024-04-11 13:42:10', 'position_address': 'Hardwicke Place, Rotunda A Ward 1986, Dublin, County Dublin, Leinster, D01 T3F2, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c62'), 'number': 77, 'contract_name': 'dublin', 'name': 'WOLFE TONE STREET', 'address': 'Wolfe Tone Street', 'bike_stands': 29, 'available_bike_stands': 25, 'available_bikes': 4, 'status': 'OPEN', 'last_update': '2024-04-11 13:44:04', 'position_address': 'Wolfe Tone Street, North City Ward 1986, Dublin, County Dublin, Leinster, D01 YX64, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c63'), 'number': 73, 'contract_name': 'dublin', 'name': 'FRANCIS STREET', 'address': 'Francis Street', 'bike_stands': 30, 'available_bike_stands': 29, 'available_bikes': 1, 'status': 'OPEN', 'last_update': '2024-04-11 13:43:42', 'position_address': 'Francis Street, The Liberties, Merchants Quay B ED, Dublin, County Dublin, Leinster, D08 F2RN, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c64'), 'number': 4, 'contract_name': 'dublin', 'name': 'GREEK STREET', 'address': 'Greek Street', 'bike_stands': 20, 'available_bike_stands': 2, 'available_bikes': 18, 'status': 'OPEN', 'last_update': '2024-04-11 13:44:51', 'position_address': 'Greek Street, Inns Quay C Ward 1986, Dublin, County Dublin, Leinster, D07 KX21, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c65'), 'number': 49, 'contract_name': 'dublin', 'name': 'GUILD STREET', 'address': 'Guild Street', 'bike_stands': 40, 'available_bike_stands': 29, 'available_bikes': 11, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:58', 'position_address': 'Guild Street, North Dock C ED, Dublin, County Dublin, Leinster, D01 E4X0, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c66'), 'number': 19, 'contract_name': 'dublin', 'name': 'HERBERT PLACE', 'address': 'Herbert Place', 'bike_stands': 30, 'available_bike_stands': 8, 'available_bikes': 22, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:53', 'position_address': 'Herbert Place, South Dock ED, Dublin, County Dublin, Leinster, D04 WN52, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c67'), 'number': 7, 'contract_name': 'dublin', 'name': 'HIGH STREET', 'address': 'High Street', 'bike_stands': 29, 'available_bike_stands': 29, 'available_bikes': 0, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:34', 'position_address': 'Bridge Street Upper, Merchants Quay A Ward 1986, Dublin, County Dublin, Leinster, D08 CX34, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c68'), 'number': 60, 'contract_name': 'dublin', 'name': 'NORTH CIRCULAR ROAD', 'address': 'North Circular Road', 'bike_stands': 30, 'available_bike_stands': 16, 'available_bikes': 14, 'status': 'OPEN', 'last_update': '2024-04-11 13:44:22', 'position_address': 'Dublin One, 493-511, North Circular Road, Ballybough B ED, Dublin, County Dublin, Leinster, D01 A2Y2, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c69'), 'number': 102, 'contract_name': 'dublin', 'name': 'WESTERN WAY', 'address': 'Western Way', 'bike_stands': 40, 'available_bike_stands': 31, 'available_bikes': 9, 'status': 'OPEN', 'last_update': '2024-04-11 13:43:08', 'position_address': 'Western Way, Inns Quay B Ward 1986, Dublin, County Dublin, Leinster, D07 X923, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c6a'), 'number': 38, 'contract_name': 'dublin', 'name': 'TALBOT STREET', 'address': 'Talbot Street', 'bike_stands': 40, 'available_bike_stands': 39, 'available_bikes': 1, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:23', 'position_address': '74 Talbot, 74, Talbot Street, Mountjoy A Ward 1986, Dublin, County Dublin, Leinster, D01 E4H9, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c6b'), 'number': 53, 'contract_name': 'dublin', 'name': 'NEWMAN HOUSE', 'address': 'Newman House', 'bike_stands': 40, 'available_bike_stands': 31, 'available_bikes': 9, 'status': 'OPEN', 'last_update': '2024-04-11 13:44:31', 'position_address': 'Mansion House B ED, Dublin, County Dublin, Leinster, D02 VH98, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c6c'), 'number': 58, 'contract_name': 'dublin', 'name': "SIR PATRICK DUN'S", 'address': "Sir Patrick's Dun", 'bike_stands': 40, 'available_bike_stands': 27, 'available_bikes': 13, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:22', 'position_address': 'Grand Canal Street Lower, South Dock ED, Dublin, County Dublin, Leinster, D02 FF61, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c6d'), 'number': 66, 'contract_name': 'dublin', 'name': 'NEW CENTRAL BANK', 'address': 'New Central Bank', 'bike_stands': 40, 'available_bike_stands': 33, 'available_bikes': 7, 'status': 'OPEN', 'last_update': '2024-04-11 13:43:09', 'position_address': 'North Wall Quay, North Wall, North Dock B Ward 1986, Dublin, County Dublin, Leinster, D01 V4A3, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c6e'), 'number': 104, 'contract_name': 'dublin', 'name': 'GRANGEGORMAN LOWER (CENTRAL)', 'address': 'Grangegorman Lower (Central)', 'bike_stands': 40, 'available_bike_stands': 32, 'available_bikes': 8, 'status': 'OPEN', 'last_update': '2024-04-11 13:44:35', 'position_address': 'Grangegorman, Grangegorman Lower, Grangegorman, Arran Quay B ED, Dublin, County Dublin, Leinster, D07 XT95, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c6f'), 'number': 101, 'contract_name': 'dublin', 'name': 'KING STREET NORTH', 'address': 'King Street North', 'bike_stands': 30, 'available_bike_stands': 28, 'available_bikes': 2, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:29', 'position_address': 'King Street North, North King Street, Inns Quay C Ward 1986, Dublin, County Dublin, Leinster, D07 E128, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c70'), 'number': 115, 'contract_name': 'dublin', 'name': 'KILLARNEY STREET', 'address': 'Killarney Street', 'bike_stands': 30, 'available_bike_stands': 30, 'available_bikes': 0, 'status': 'OPEN', 'last_update': '2024-04-11 13:37:45', 'position_address': 'Killarney Street, Mountjoy A ED, Dublin, County Dublin, Leinster, D01 HN36, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c71'), 'number': 47, 'contract_name': 'dublin', 'name': 'HERBERT STREET', 'address': 'Herbert Street', 'bike_stands': 40, 'available_bike_stands': 29, 'available_bikes': 11, 'status': 'OPEN', 'last_update': '2024-04-11 13:42:18', 'position_address': 'The Plantation, 1-9, Herbert Street, South Dock ED, Dublin, County Dublin, Leinster, D02 FK19, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c72'), 'number': 117, 'contract_name': 'dublin', 'name': 'HANOVER QUAY EAST', 'address': 'Hanover Quay East', 'bike_stands': 40, 'available_bike_stands': 28, 'available_bikes': 12, 'status': 'OPEN', 'last_update': '2024-04-11 13:42:19', 'position_address': 'Hanover Quay East, Hanover Quay, Dublin Docklands, South Dock ED, Dublin, County Dublin, Leinster, D02 DP23, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c73'), 'number': 8, 'contract_name': 'dublin', 'name': 'CUSTOM HOUSE QUAY', 'address': 'Custom House Quay', 'bike_stands': 30, 'available_bike_stands': 17, 'available_bikes': 13, 'status': 'OPEN', 'last_update': '2024-04-11 13:44:51', 'position_address': 'Custom House Quay, North Dock C ED, Dublin, County Dublin, Leinster, D01 KF84, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c74'), 'number': 27, 'contract_name': 'dublin', 'name': 'MOLESWORTH STREET', 'address': 'Molesworth Street', 'bike_stands': 20, 'available_bike_stands': 15, 'available_bikes': 5, 'status': 'OPEN', 'last_update': '2024-04-11 13:46:00', 'position_address': '40 Molesworth Street, 40, Molesworth Street, Mansion House B Ward 1986, Dublin, County Dublin, Leinster, D02 TF98, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c75'), 'number': 16, 'contract_name': 'dublin', 'name': 'GEORGES QUAY', 'address': 'Georges Quay', 'bike_stands': 20, 'available_bike_stands': 20, 'available_bikes': 0, 'status': 'OPEN', 'last_update': '2024-04-11 13:41:45', 'position_address': "George's Quay, Mansion House A Ward 1986, Dublin, County Dublin, Leinster, D02 DY01, Éire / Ireland"}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c76'), 'number': 96, 'contract_name': 'dublin', 'name': 'KILMAINHAM LANE', 'address': 'Kilmainham Lane', 'bike_stands': 30, 'available_bike_stands': 17, 'available_bikes': 13, 'status': 'OPEN', 'last_update': '2024-04-11 13:42:25', 'position_address': 'Kilmainham Lane, Kilmainham, Ushers A Ward 1986, Dublin, County Dublin, Leinster, D08 DK2K, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c77'), 'number': 82, 'contract_name': 'dublin', 'name': 'MOUNT BROWN', 'address': 'Mount Brown', 'bike_stands': 22, 'available_bike_stands': 22, 'available_bikes': 0, 'status': 'OPEN', 'last_update': '2024-04-11 13:42:21', 'position_address': 'Mount Brown, Ushers A Ward 1986, Dublin, County Dublin, Leinster, D08 CY51, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c78'), 'number': 76, 'contract_name': 'dublin', 'name': 'MARKET STREET SOUTH', 'address': 'Market Street South', 'bike_stands': 38, 'available_bike_stands': 27, 'available_bikes': 11, 'status': 'OPEN', 'last_update': '2024-04-11 13:42:08', 'position_address': 'Grand Canal Place, Ushers C Ward 1986, Dublin, County Dublin, Leinster, D08 HX3K, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c79'), 'number': 71, 'contract_name': 'dublin', 'name': 'KEVIN STREET', 'address': 'Kevin Street', 'bike_stands': 40, 'available_bike_stands': 33, 'available_bikes': 7, 'status': 'OPEN', 'last_update': '2024-04-11 13:42:49', 'position_address': 'Kevin Street Lower, Royal Exchange A Ward 1986, Dublin, County Dublin, Leinster, D02 TD99, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c7a'), 'number': 79, 'contract_name': 'dublin', 'name': 'ECCLES STREET EAST', 'address': 'Eccles Street East', 'bike_stands': 27, 'available_bike_stands': 22, 'available_bikes': 5, 'status': 'OPEN', 'last_update': '2024-04-11 13:36:12', 'position_address': 'Eccles Street east, Eccles Street, Inns Quay A Ward 1986, Dublin, County Dublin, Leinster, D01 T3F2, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c7b'), 'number': 69, 'contract_name': 'dublin', 'name': 'GRAND CANAL DOCK', 'address': 'Grand Canal Dock', 'bike_stands': 40, 'available_bike_stands': 2, 'available_bikes': 38, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:15', 'position_address': 'Cafe Bar H, 1, Grand Canal Square, Dublin Docklands, South Dock ED, Dublin, County Dublin, Leinster, D02 E295, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c7c'), 'number': 25, 'contract_name': 'dublin', 'name': 'MERRION SQUARE EAST', 'address': 'Merrion Square East', 'bike_stands': 30, 'available_bike_stands': 6, 'available_bikes': 24, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:47', 'position_address': '37, Merrion Square East, South Dock ED, Dublin, County Dublin, Leinster, D01 VY60, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c7d'), 'number': 51, 'contract_name': 'dublin', 'name': 'YORK STREET WEST', 'address': 'York Street West', 'bike_stands': 40, 'available_bike_stands': 40, 'available_bikes': 0, 'status': 'OPEN', 'last_update': '2024-04-11 13:42:17', 'position_address': 'The Swan, 57-58, York Street, Royal Exchange B ED, Dublin, County Dublin, Leinster, D02 RW67, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c7e'), 'number': 37, 'contract_name': 'dublin', 'name': "ST. STEPHEN'S GREEN SOUTH", 'address': "St. Stephen's Green South", 'bike_stands': 30, 'available_bike_stands': 17, 'available_bikes': 13, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:03', 'position_address': "Superintendant's Lodge, St. Stephen's Green, Mansion House B Ward 1986, Dublin, County Dublin, Leinster, D02 HD86, Éire / Ireland"}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c7f'), 'number': 59, 'contract_name': 'dublin', 'name': 'DENMARK STREET GREAT', 'address': 'Denmark Street Great', 'bike_stands': 20, 'available_bike_stands': 18, 'available_bikes': 2, 'status': 'OPEN', 'last_update': '2024-04-11 13:44:30', 'position_address': '21, Great Denmark Street, Rotunda A Ward 1986, Dublin, County Dublin, Leinster, D01 PP66, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c80'), 'number': 95, 'contract_name': 'dublin', 'name': 'ROYAL HOSPITAL', 'address': 'Royal Hospital', 'bike_stands': 40, 'available_bike_stands': 32, 'available_bikes': 8, 'status': 'OPEN', 'last_update': '2024-04-11 13:43:49', 'position_address': 'Royal Hospital, Military Road, Kilmainham, Ushers A Ward 1986, Dublin, County Dublin, Leinster, D08 A9DT, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c81'), 'number': 94, 'contract_name': 'dublin', 'name': 'HEUSTON STATION (CAR PARK)', 'address': 'Heuston Station (Car Park)', 'bike_stands': 40, 'available_bike_stands': 37, 'available_bikes': 3, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:05', 'position_address': "Heuston Station, Saint John's Road West, Kilmainham, Ushers A Ward 1986, Dublin, County Dublin, Leinster, D08 A9DT, Éire / Ireland"}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c82'), 'number': 105, 'contract_name': 'dublin', 'name': 'GRANGEGORMAN LOWER (NORTH)', 'address': 'Grangegorman Lower (North)', 'bike_stands': 36, 'available_bike_stands': 28, 'available_bikes': 8, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:14', 'position_address': 'Grangegorman, Rathdown Road, Grangegorman, Arran Quay B ED, Dublin, County Dublin, Leinster, D07 XT95, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c83'), 'number': 36, 'contract_name': 'dublin', 'name': "ST. STEPHEN'S GREEN EAST", 'address': "St. Stephen's Green East", 'bike_stands': 40, 'available_bike_stands': 25, 'available_bikes': 15, 'status': 'OPEN', 'last_update': '2024-04-11 13:41:45', 'position_address': "St. Stephen's Green, Mansion House B ED, Dublin, County Dublin, Leinster, D02 HK52, Éire / Ireland"}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c84'), 'number': 93, 'contract_name': 'dublin', 'name': 'HEUSTON STATION (CENTRAL)', 'address': 'Heuston Station (Central)', 'bike_stands': 40, 'available_bike_stands': 39, 'available_bikes': 1, 'status': 'OPEN', 'last_update': '2024-04-11 13:43:35', 'position_address': "Heuston Station, Saint John's Road West, Kilmainham, Ushers A Ward 1986, Dublin, County Dublin, Leinster, D08 A9DT, Éire / Ireland"}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c85'), 'number': 22, 'contract_name': 'dublin', 'name': 'TOWNSEND STREET', 'address': 'Townsend Street', 'bike_stands': 20, 'available_bike_stands': 15, 'available_bikes': 5, 'status': 'OPEN', 'last_update': '2024-04-11 13:43:29', 'position_address': 'Townsend Street, Mansion House A Ward 1986, Dublin, County Dublin, Leinster, D02 TK71, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c86'), 'number': 50, 'contract_name': 'dublin', 'name': 'GEORGES LANE', 'address': "George's Lane", 'bike_stands': 40, 'available_bike_stands': 38, 'available_bikes': 2, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:49', 'position_address': "George's Lane, Stoneybatter, Arran Quay B ED, Dublin, County Dublin, Leinster, D07 E98Y, Éire / Ireland"}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c87'), 'number': 110, 'contract_name': 'dublin', 'name': 'PHIBSBOROUGH ROAD', 'address': 'Phibsborough Road', 'bike_stands': 40, 'available_bike_stands': 38, 'available_bikes': 2, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:31', 'position_address': 'dublinbikes, Royal Canal Terrace, Arran Quay A Ward 1986, Dublin, County Dublin, Leinster, D07 A562, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c88'), 'number': 12, 'contract_name': 'dublin', 'name': 'ECCLES STREET', 'address': 'Eccles Street', 'bike_stands': 20, 'available_bike_stands': 17, 'available_bikes': 3, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:23', 'position_address': 'Eccles Street, Inns Quay B ED, Dublin, County Dublin, Leinster, D07 WKW8, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c89'), 'number': 34, 'contract_name': 'dublin', 'name': 'PORTOBELLO HARBOUR', 'address': 'Portobello Harbour', 'bike_stands': 30, 'available_bike_stands': 19, 'available_bikes': 11, 'status': 'OPEN', 'last_update': '2024-04-11 13:46:02', 'position_address': "Portobello Harbour, Portobello, Saint Kevin's ED, Dublin, County Dublin, Leinster, D06 C780, Éire / Ireland"}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c8a'), 'number': 78, 'contract_name': 'dublin', 'name': 'MATER HOSPITAL', 'address': 'Mater Hospital', 'bike_stands': 40, 'available_bike_stands': 32, 'available_bikes': 8, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:45', 'position_address': 'Mater Misericordiae University Hospital, North Circular Road, Inns Quay A ED, Dublin, County Dublin, Leinster, D07 K188, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c8b'), 'number': 2, 'contract_name': 'dublin', 'name': 'BLESSINGTON STREET', 'address': 'Blessington Street', 'bike_stands': 20, 'available_bike_stands': 12, 'available_bikes': 8, 'status': 'OPEN', 'last_update': '2024-04-11 13:42:47', 'position_address': 'Meridian Clinic, 56, Blessington Street, Inns Quay B ED, Dublin, County Dublin, Leinster, D01 V6X5, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c8c'), 'number': 75, 'contract_name': 'dublin', 'name': 'JAMES STREET', 'address': 'James Street', 'bike_stands': 40, 'available_bike_stands': 11, 'available_bikes': 29, 'status': 'OPEN', 'last_update': '2024-04-11 13:36:44', 'position_address': "Open Gate Taproom, 53, James's Street, Ushers C ED, Dublin, County Dublin, Leinster, D08 X20N, Éire / Ireland"}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c8d'), 'number': 111, 'contract_name': 'dublin', 'name': 'MOUNTJOY SQUARE EAST', 'address': 'Mountjoy Square East', 'bike_stands': 40, 'available_bike_stands': 40, 'available_bikes': 0, 'status': 'OPEN', 'last_update': '2024-04-11 13:41:50', 'position_address': 'Mountjoy Square South, Mountjoy Square, Mountjoy B ED, Dublin, County Dublin, Leinster, D01 PK61, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c8e'), 'number': 26, 'contract_name': 'dublin', 'name': 'MERRION SQUARE WEST', 'address': 'Merrion Square West', 'bike_stands': 20, 'available_bike_stands': 11, 'available_bikes': 8, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:58', 'position_address': '87, Merrion Square South, Mansion House B Ward 1986, Dublin, County Dublin, Leinster, D02 R206, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c8f'), 'number': 65, 'contract_name': 'dublin', 'name': 'CONVENTION CENTRE', 'address': 'Convention Centre', 'bike_stands': 40, 'available_bike_stands': 31, 'available_bikes': 9, 'status': 'OPEN', 'last_update': '2024-04-11 13:43:32', 'position_address': 'PwC, 1, North Wall Quay, North Wall, North Dock B Ward 1986, Dublin, County Dublin, Leinster, D01 T1W6, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c90'), 'number': 15, 'contract_name': 'dublin', 'name': 'HARDWICKE STREET', 'address': 'Hardwicke Street', 'bike_stands': 16, 'available_bike_stands': 12, 'available_bikes': 4, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:32', 'position_address': '48, Hardwicke Street, Rotunda A Ward 1986, Dublin, County Dublin, Leinster, D01 AW02, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c91'), 'number': 86, 'contract_name': 'dublin', 'name': 'PARKGATE STREET', 'address': 'Parkgate Street', 'bike_stands': 38, 'available_bike_stands': 35, 'available_bikes': 3, 'status': 'OPEN', 'last_update': '2024-04-11 13:44:32', 'position_address': 'Parkgate Street, Rialto, Arran Quay D ED, Dublin, County Dublin, Leinster, D08 XR94, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c92'), 'number': 35, 'contract_name': 'dublin', 'name': 'SMITHFIELD', 'address': 'Smithfield', 'bike_stands': 30, 'available_bike_stands': 17, 'available_bikes': 13, 'status': 'OPEN', 'last_update': '2024-04-11 13:36:05', 'position_address': 'Smithfield, Arran Quay C ED, Dublin, County Dublin, Leinster, D07 WR63, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c93'), 'number': 10, 'contract_name': 'dublin', 'name': 'DAME STREET', 'address': 'Dame Street', 'bike_stands': 16, 'available_bike_stands': 8, 'available_bikes': 8, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:51', 'position_address': 'Barnardo Square, Royal Exchange A Ward 1986, Dublin, County Dublin, Leinster, D02 VW57, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c94'), 'number': 100, 'contract_name': 'dublin', 'name': 'HEUSTON BRIDGE (SOUTH)', 'address': 'Heuston Bridge (South)', 'bike_stands': 25, 'available_bike_stands': 17, 'available_bikes': 8, 'status': 'OPEN', 'last_update': '2024-04-11 13:37:12', 'position_address': 'Heuston Station, Kilmainham, Ushers A ED, Dublin, County Dublin, Leinster, D08 E2CV, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c95'), 'number': 24, 'contract_name': 'dublin', 'name': 'CATHAL BRUGHA STREET', 'address': 'Cathal Brugha Street', 'bike_stands': 20, 'available_bike_stands': 16, 'available_bikes': 4, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:49', 'position_address': 'Findlater Place, Rotunda A Ward 1986, Dublin, County Dublin, Leinster, D01 V082, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c96'), 'number': 64, 'contract_name': 'dublin', 'name': 'SANDWITH STREET', 'address': 'Sandwith Street', 'bike_stands': 40, 'available_bike_stands': 29, 'available_bikes': 11, 'status': 'OPEN', 'last_update': '2024-04-11 13:41:43', 'position_address': 'Dublin South East Community Training Centre, 88-90, Townsend Street, Mansion House A Ward 1986, Dublin, County Dublin, Leinster, D02 Y729, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c97'), 'number': 109, 'contract_name': 'dublin', 'name': 'BUCKINGHAM STREET LOWER', 'address': 'Buckingham Street Lower', 'bike_stands': 29, 'available_bike_stands': 25, 'available_bikes': 4, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:02', 'position_address': 'Buckingham Street Lower, Mountjoy A ED, Dublin, County Dublin, Leinster, D01 WV02, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c98'), 'number': 85, 'contract_name': 'dublin', 'name': 'ROTHE ABBEY', 'address': 'Rothe Abbey', 'bike_stands': 35, 'available_bike_stands': 12, 'available_bikes': 23, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:44', 'position_address': '1, Rothe Abbey, Ushers F Ward 1986, Dublin, County Dublin, Leinster, D08 EP8E, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c99'), 'number': 107, 'contract_name': 'dublin', 'name': 'CHARLEVILLE ROAD', 'address': 'Charleville Road', 'bike_stands': 40, 'available_bike_stands': 27, 'available_bikes': 13, 'status': 'OPEN', 'last_update': '2024-04-11 13:44:24', 'position_address': '2, Charleville Road, Cabra East C ED, Dublin, County Dublin, Leinster, D07 A025, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c9a'), 'number': 33, 'contract_name': 'dublin', 'name': "PRINCES STREET / O'CONNELL STREET", 'address': "Princes Street / O'Connell Street", 'bike_stands': 23, 'available_bike_stands': 2, 'available_bikes': 21, 'status': 'OPEN', 'last_update': '2024-04-11 13:44:48', 'position_address': "Prince's Street North, North City Ward 1986, Dublin, County Dublin, Leinster, D01 F5P2, Éire / Ireland"}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c9b'), 'number': 44, 'contract_name': 'dublin', 'name': 'UPPER SHERRARD STREET', 'address': 'Upper Sherrard Street', 'bike_stands': 30, 'available_bike_stands': 26, 'available_bikes': 4, 'status': 'OPEN', 'last_update': '2024-04-11 13:44:34', 'position_address': 'Sherrard Street Upper, Mountjoy B ED, Dublin, County Dublin, Leinster, D01 C2F6, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c9c'), 'number': 89, 'contract_name': 'dublin', 'name': 'FITZWILLIAM SQUARE EAST', 'address': 'Fitzwilliam Square East', 'bike_stands': 40, 'available_bike_stands': 34, 'available_bikes': 6, 'status': 'OPEN', 'last_update': '2024-04-11 13:44:59', 'position_address': 'Fitzwilliam Square East, Mansion House B ED, Dublin, County Dublin, Leinster, D02 F891, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c9d'), 'number': 57, 'contract_name': 'dublin', 'name': 'GRATTAN STREET', 'address': 'Grattan Street', 'bike_stands': 23, 'available_bike_stands': 19, 'available_bikes': 4, 'status': 'OPEN', 'last_update': '2024-04-11 13:42:33', 'position_address': '10, Grattan Street, South Dock ED, Dublin, County Dublin, Leinster, D02 HD59, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c9e'), 'number': 80, 'contract_name': 'dublin', 'name': 'ST JAMES HOSPITAL (LUAS)', 'address': 'St James Hospital (Luas)', 'bike_stands': 40, 'available_bike_stands': 31, 'available_bikes': 9, 'status': 'OPEN', 'last_update': '2024-04-11 13:42:26', 'position_address': "St. James's Hospital, James's Street, Ushers F ED, Dublin, County Dublin, Leinster, D08 NHY1, Éire / Ireland"}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249c9f'), 'number': 41, 'contract_name': 'dublin', 'name': 'HARCOURT TERRACE', 'address': 'Harcourt Terrace', 'bike_stands': 20, 'available_bike_stands': 18, 'available_bikes': 2, 'status': 'OPEN', 'last_update': '2024-04-11 13:44:41', 'position_address': 'Adelaide House, 19, Adelaide Road, Saint Kevins Ward 1986, Dublin, County Dublin, Leinster, D02 H337, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249ca0'), 'number': 3, 'contract_name': 'dublin', 'name': 'BOLTON STREET', 'address': 'Bolton Street', 'bike_stands': 20, 'available_bike_stands': 13, 'available_bikes': 7, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:32', 'position_address': 'Capel Street, Rotunda B Ward 1986, Dublin, County Dublin, Leinster, D01 CK40, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249ca1'), 'number': 40, 'contract_name': 'dublin', 'name': 'JERVIS STREET', 'address': 'Jervis Street', 'bike_stands': 21, 'available_bike_stands': 8, 'available_bikes': 13, 'status': 'OPEN', 'last_update': '2024-04-11 13:42:46', 'position_address': 'Jervis Street, North City ED, Dublin, County Dublin, Leinster, D01 R2P0, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249ca2'), 'number': 29, 'contract_name': 'dublin', 'name': 'ORMOND QUAY UPPER', 'address': 'Ormond Quay Upper', 'bike_stands': 29, 'available_bike_stands': 4, 'available_bikes': 25, 'status': 'OPEN', 'last_update': '2024-04-11 13:45:15', 'position_address': 'OpenJaw Technologies, 1-3, Ormond Quay Upper, North City ED, Dublin, County Dublin, Leinster, D07 YK6A, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249ca3'), 'number': 103, 'contract_name': 'dublin', 'name': 'GRANGEGORMAN LOWER (SOUTH)', 'address': 'Grangegorman Lower (South)', 'bike_stands': 40, 'available_bike_stands': 32, 'available_bikes': 8, 'status': 'OPEN', 'last_update': '2024-04-11 13:43:23', 'position_address': 'Grangegorman, Grangegorman Lower, Grangegorman, Arran Quay B ED, Dublin, County Dublin, Leinster, D07 XT95, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249ca4'), 'number': 28, 'contract_name': 'dublin', 'name': 'MOUNTJOY SQUARE WEST', 'address': 'Mountjoy Square West', 'bike_stands': 30, 'available_bike_stands': 30, 'available_bikes': 0, 'status': 'OPEN', 'last_update': '2024-04-11 13:44:27', 'position_address': '61, Mountjoy Square West, Mountjoy Square, Rotunda A Ward 1986, Dublin, County Dublin, Leinster, D01 K286, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249ca5'), 'number': 39, 'contract_name': 'dublin', 'name': 'WILTON TERRACE', 'address': 'Wilton Terrace', 'bike_stands': 20, 'available_bike_stands': 20, 'available_bikes': 0, 'status': 'OPEN', 'last_update': '2024-04-11 13:44:56', 'position_address': 'Wilton Terrace, South Dock ED, Dublin, County Dublin, Leinster, D02 H337, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249ca6'), 'number': 83, 'contract_name': 'dublin', 'name': 'EMMET ROAD', 'address': 'Emmet Road', 'bike_stands': 40, 'available_bike_stands': 31, 'available_bikes': 9, 'status': 'OPEN', 'last_update': '2024-04-11 13:44:25', 'position_address': 'Emmet Road, Kilmainham C Ward 1986, Dublin, County Dublin, Leinster, D08 F9H3, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249ca7'), 'number': 92, 'contract_name': 'dublin', 'name': 'HEUSTON BRIDGE (NORTH)', 'address': 'Heuston Bridge (North)', 'bike_stands': 40, 'available_bike_stands': 36, 'available_bikes': 4, 'status': 'OPEN', 'last_update': '2024-04-11 13:44:05', 'position_address': 'Parkgate Street, Islandbridge, Phoenix Park ED, Dublin, County Dublin, Leinster, D08 XR94, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249ca8'), 'number': 21, 'contract_name': 'dublin', 'name': 'LEINSTER STREET SOUTH', 'address': 'Leinster Street South', 'bike_stands': 30, 'available_bike_stands': 9, 'available_bikes': 21, 'status': 'OPEN', 'last_update': '2024-04-11 13:44:27', 'position_address': 'Leinster Street South, Mansion House A Ward 1986, Dublin, County Dublin, Leinster, D02 TR76, Éire / Ireland'}
# {'_id': ObjectId('6617dbf14a7d0d8ef6249ca9'), 'number': 88, 'contract_name': 'dublin', 'name': 'BLACKHALL PLACE', 'address': 'Blackhall Place', 'bike_stands': 30, 'available_bike_stands': 27, 'available_bikes': 3, 'status': 'OPEN', 'last_update': '2024-04-11 13:43:49', 'position_address': 'Blackhall, Blackhall Street, Smithfield, Arran Quay C Ward 1986, Dublin, County Dublin, Leinster, D07 T4CN, Éire / Ireland'}

# %% [markdown]
# ## Creating a pipeline to fetch live data every 60 minutes with transformations on the data and uploading it to mongo db server

# %% [markdown]
# ### Defining all the function below again for the ease of understanding

# %%
#defined function for data fetching from api
def data_fetch():
    api_key = "9c31defb68c5ac281ef53ad13569fa29d295e408"
    endpoint = f"https://api.jcdecaux.com/vls/v1/stations?contract=dublin&apiKey={api_key}"
    response = requests.get(endpoint)
    data_acq = response.json()
    df = pd.DataFrame(data_acq)
    return df

# %%
# defining data transformations

def data_transform(data):
    data['last_update'] = data['last_update'].apply(time_stamp_convert)
    data[['latitude', 'longitude']] = data['position'].apply(pd.Series)
    data['position_address'] = data.apply(lambda row: reverse_geocode(row['latitude'], row['longitude']), axis=1)
    data = data.drop(columns=["position","banking","bonus","latitude","longitude"])
    return data

# %%
# defining uploading the data to mongo db server
def upload_mongo(data):
    data_dic = data.to_dict(orient='records')
    collection.insert_many(data_dic)

# %% [markdown]
# ### Defining pipeline

# %%
from datetime import datetime
import time

def pipeline():
    # Running the pipeline for 10 hours
    end_time = time.time() + (10 * 60 * 60)  # 10 hours * 60 minutes * 60 seconds

    while time.time() < end_time:
        # Fetching data from API
        print("Fetching data from API.....")
        data = data_fetch()
        print("Fetching success!\n")

        # Transforming data
        print("Applying Transformations....")
        df = data_transform(data)
        print("Transformations Applied!\n")

        # Uploading data to MongoDB
        print("Uploading data to mongo db server...../")
        upload_mongo(df)
        print("Upload Success!\n")

        # Waiting for 10 minutes before fetching data again
        print("Waiting for 10 minutes before fetching data again.....\n\n")      
        time.sleep(600)  # 10 minutes * 60 seconds = 600 seconds

# %%
# Running the pipeline
pipeline()
# Out:
# Fetching data from API.....
# Fetching success!
#
# Applying Transformations....
# Transformations Applied!
#
# Uploading data to mongo db server...../
# Upload Success!
#
# Waiting for 10 minutes before fetching data again.....
#
#
# Fetching data from API.....
# Fetching success!
#
# Applying Transformations....
# Transformations Applied!
#
# Uploading data to mongo db server...../
# Upload Success!
#
# Waiting for 10 minutes before fetching data again.....
#
#
# Fetching data from API.....
# Fetching success!
#
# Applying Transformations....
# Transformations Applied!
#
# Uploading data to mongo db server...../
# Upload Success!
#
# Waiting for 10 minutes before fetching data again.....

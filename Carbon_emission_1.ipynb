# %%
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

# %%
url='https://roadmap2030.ceres.org/companies-action'

# %%
resp = requests.get(url)

# %%
resp
# Out:
# <Response [200]>

# %%
resp.content
# Out:
# b'<!DOCTYPE html>\n<html  lang="en" dir="ltr" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">\n  <head>\n    <meta charset="utf-8" />\n<meta name="robots" content="index, follow" />\n<link rel="canonical" href="https://roadmap2030.ceres.org/companies-action" />\n<meta name="keywords" content="Ceres Roadmap 2030, sustainable, business, leadership, action plan" />\n<meta name="Generator" content="Drupal 8 (https://www.drupal.org)" />\n<meta name="MobileOptimized" content="width" />\n<meta name="HandheldFriendly" content="true" />\n<meta name="viewport" content="width=device-width, initial-scale=1.0" />\n<style>div#sliding-popup, div#sliding-popup .eu-cookie-withdraw
# ...

# %%
soup = BeautifulSoup(resp.content, 'html.parser')

# %%
ul=soup.find('ul',{'class' : "menu menu--main nav navbar-nav"})

# %%
items = soup.find_all('h3',{'class' : "node-title"})

# %%
len(items)
# Out:
# 15

# %%
items
# Out:
# [<h3 class="node-title"><span>JLL</span>
#  </h3>,
#  <h3 class="node-title"><span>Bunge</span>
#  </h3>,
#  <h3 class="node-title"><span>Best Buy</span>
#  </h3>,
#  <h3 class="node-title"><span>Microsoft</span>
#  </h3>,
#  <h3 class="node-title"><span>Morgan Stanley</span>
#  </h3>,
#  <h3 class="node-title"><span>Cisco</span>
#  </h3>,
#  <h3 class="node-title"><span>Walmart</span>
#  </h3>,
#  <h3 class="node-title"><span>Unilever</span>
#  </h3>,
#  <h3 class="node-title"><span>Nestlé</span>
#  </h3>,
#  <h3 class="node-title"><span>Google</span>
#  </h3>,
#  <h3 class="node-title"><span>General Mills</span>
#  </h3>,
#  <h3 class="node-title"><span>Apple</span>
#  </h3>,
#  <h3 class="node-title"><span>IKEA</span>
#  </h3>,
#  <h3 class="node-title"><span>Clif Bar &amp; Company</span>
#  </h3>,
#  <h3 class="node-title"><span>Amazon</span>
#  </h3>]
